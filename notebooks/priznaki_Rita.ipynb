# %%
import pandas as pd
# train_actions -  перечислены действия, которые пользователи совершили после показа рекламы.

# time - время события
# ssp_event_id -  Идентификатор показа рекламы. Используйте его, чтобы сопоставить показ рекламы с кликами по рекламе и конверсиям.
# clicks - 0 - нет клика по рекламы, 1 - клик по рекламе. Данной колонки не будет в тестовом датасете
# conversion_name - тип конверсии (см. доп. таблицу)
# is_post_click -  Если это значение равно 1, это означает, что человек кликнул на вашу рекламу, а затем сделал то, что вы хотели. Например, это может быть покупка товара или заполнение формы. 
# is_post_view -  Если это значение равно 1, это означает, что человек увидел вашу рекламу, но не кликнул на неё, а затем сделал то, что вы хотели. Если значение равно 0, это означает, что человек сделал то, что вы хотели, но без просмотра рекламы.
train_actions = pd.read_parquet('train_actions.parquet')
train_actions = train_actions.head(10000)
train_actions
# Out:
#                      time  ssp_event_id  clicks   conversion_name  \
# 0     2024-01-02 21:36:50  uxxLGVvM1aOs       0           pereyti
# 1     2024-01-02 21:08:31   M9no149TZAc       0           pereyti
# 2     2024-01-02 21:23:01   xY4srE5hee8       0           pereyti
# 3     2024-01-02 21:28:09   0gcd7iQx2H9       0           pereyti
# 4     2024-01-02 21:06:44   s0snGGmhlNa       0           pereyti
# ...                   ...           ...     ...               ...
# 9995  2024-01-05 14:53:18   xpxyQMl8zrY       0           pereyti
# 9996  2024-01-05 14:53:18   xpxyQMl8zrY       0  implicit_depth_2
# 9997  2024-01-05 14:54:05   xpxyQMl8zrY       0  implicit_depth_2
# 9998  2024-01-05 14:54:05   xpxyQMl8zrY       0  implicit_depth_3
# 9999  2024-01-05 14:54:05   xpxyQMl8zrY       0  implicit_depth_5
#
#       is_post_click  is_post_view
# 0                 1             0
# 1                 1             0
# 2                 1             0
# 3                 1             0
# 4                 1             0
# ...             ...           ...
# 9995              0             1
# 9996              0             1
# 9997              0             1
# 9998              0             1
# 9999              0             1
#
# [10000 rows x 6 columns]

# %% [markdown]
# | Feature_name           | Description                                                                                     |
# |------------------------|-------------------------------------------------------------------------------------------------|
# | bid_url                | URL-адрес, на которой происходит показ рекламы                                                 |
# | bid_referer            | Источник, откуда пользователь попал на сайт с рекламой                                         |
# | bid_user_status        | Статус пользователя (встречался ли нам он ранее и способ детекции)                             |
# | bid_ip                 | IP-адрес пользователя                                                                          |
# | bid_isp_name           | Провайдер интернета пользователя                                                               |
# | landing_page           | Страница, на которую перейдет пользователь, если кликнет по рекламе                             |
# | page_language          | Язык страницы, на которой происходит показ рекламы                                             |
# | ssp_event_id           | Идентификатор показа рекламы. Используйте его, чтобы сопоставить показ рекламы с кликами по рекламе и конверсиям |
# | ssp                    | Биржа рекламы, которая проводит аукцион рекламы с площадками, наподобие нашей                   |
# | tag_id                 | ID сайта + ID рекламного места на сайте, где происходит показ рекламы                           |
# | publisher_id           | ID поставщика рекламы                                                                          |
# | creative_size          | Размеры рекламы                                                                                |
# | creative_type          | Тип рекламы                                                                                    |
# | battr                  | Некоторые атрибуты браузера пользователя, например поддержка форматов видео                     |
# | floor_cpm              | Минимальная ставка (в руб), за которую можно показать рекламу на данном рекламном месте         |
# | visibility             | Попадает ли реклама в зону видимости пользователя, либо до нее нужно скроллить                  |
# | carrier_id             | Провайдер интернета пользователя                                                               |
# | model                  | Модель устройства пользователя                                                                 |
# | mobile_screen_size     | Размер экрана мобильного телефона                                                              |
# | screen_pixel_ratio     | Отношение пикселей устройства к разрешению экрана                                              |
# | is_https               | Протокол подключения к сайту                                                                    |
# | ibv_blocked            | Есть ли встроенная блокировка видео на данном рекламном месте                                  |
# | is_interstitial        | Заполняет ли реклама весь экран/цельный блок сайта, либо нет                                    |
# | content_category       | Категории сайта                                                                                |
# | mime_types             | Формат рекламы                                                                                 |
# | content_tags           | Тэги рекламных баннеров                                                                        |
# | iframe_state           | Наличие "умной рамки" на сайте, которая не дает рекламе расшириться за пределы рекламного места |
# | ads_txt_support        | Поддержка доменом на котором происходит показ технологии ads_txt                                |
# | historical_viewability | Историческая видимость рекламного места на сайте (надо/не надо до него скроллить)              |
# | gdpr_regulation        | Соблюдает ли сайт регламент по защите персональных данных                                       |
# | do_not_track           | Разрешен ли трекинг пользователя в настройках браузера                                          |
# | full_placement_id      | Уникальный идентификатор рекламного места в интернете                                           |
# | user_fraud_state       | Является ли пользователь фродовым                                                              |
# | is_mobile_optimized_site | Сайт оптимизирован для показа на мобильных устройствах                                          |
# | device_screen          | Размер экрана                                                                                  |
# | advertiser_id          | ID рекламодателя                                                                               |
# | creative_id            | ID баннера                                                                                     |
# | timezone_offset        | Часовой пояс                                                                                   |
# | utm_source             | UTM-метка, с которой пришел пользователь                                                        |
# | search_engine          | Поисковик, если пользователь пришел оттуда                                                      |
# | search_terms           | Поисковый запрос, если пользователь пришел из поисковика                                         |
# | user_segments          | Сегменты пользователя                                                                          |
# | time                   | Время события                                                                                   |
# | region_code            | Регион                                                                                         |
# | city                   | Город                                                                                          |
# | zip_code               | Почтовый индекс                                                                                |
# | isp_type               | Тип провайдера                                                                                 |
# | user_id                | Уникальный идентификатор пользователя внутри нашей платформы                                    |
# | user_detection_type    | Способ определения ID пользователя                                                             |
# | ud_cookie_ts           | Время, когда мы последний раз считывали куки пользователя                                       |
# | accept_encoding        | Accept-Encoding                                                                                |
# | accept_language        | Accept-Language                                                                                |
# | ua_device_type         | Тип устройства                                                                                 |
# | ua_os                  | Операционная система                                                                           |
# | ua_browser             | Браузер                                                                                        |
# | ua_third_party_cookie  | Разрешены ли куки сторонних источников                                                         |
# | ua_os_version          | Версия операционной системы                                                                    |
# | ua_browser_version     | Версия браузера                                                                                |
# | ua_parsing_type        | Способ парсинга User-Agent                                                                     |
# | ua_type                | Тип User-Agent                                                                                 |
# | user_status            | Статус пользователя (встречался ли нам он ранее и способ детекции)                             |

# %%
# Датасет содержит набор признаков, которые могут повлиять на то, совершит ли пользователь конверсию или нет. 
train_views = pd.read_parquet('train_views.parquet')
train_views = train_views.head(10000)
train_views
# Out:
#                                                 bid_url  \
# 0                           https://hd.23lordfilm-0.xyz
# 1     https://hd.8lordserial.pro/277-pacany-3-sezon-...
# 2                         https://schastlivyvmestetv.ru
# 3               https://drive2.ru/l/666115206383953104/
# 4     https://3-hd.lorfil.net/16685-8-podrug-oushena...
# ...                                                 ...
# 9995  https://hd4.23lordfilm-0.xyz/36145-igrai-ili-u...
# 9996  https://hd.15lordserials.xyz/8086-zvyozdnye-vo...
# 9997  https://xn----8sbnlcopdb4b2a6a5ci.xn--p1ai/%D0...
# 9998  https://mixnews.lv/news/2024/01/20/prikolnye-k...
# 9999  https://attention.plus/stil-zhizni/nid91875_au...
#
#                                             bid_referer  \
# 0     https://hd.23lordfilm-0.xyz/15515-odin-doma-b4...
# 1     https://hd.8lordserial.pro/277-pacany-3-sezon-...
# 2                                                  None
# 3                                                  None
# 4     https://3-hd.lorfil.net/16685-8-podrug-oushena...
# ...                                                 ...
# 9995                                               None
# 9996                                               None
# 9997                                               None
# 9998                                               None
# 9999                                               None
#
#                                 bid_ip                   bid_isp_name  \
# 0     7f7cae3961b13a171daba1d5f373b58e                     Subnet LLC
# 1     5088e30457fb86e2db68ae6aba983d53                     ER-Telecom
# 2     3d563122099bdeba9c18cf39f64e29e9                   Beeline Home
# 3     c3d678eab044b889e444d29f56674e06              Shark Telecom LLC
# 4     e31e1c1211aae15e91af5945611eb7d4  Moscow City Telephone Network
# ...                                ...                            ...
# 9995  9b5d339a9eb50fd9e11fc4ff726f3223                   Beeline Home
# 9996  c9a828374d48640dfd22b3f4eeb0760c                     Rostelecom
# 9997  e68a543d26d833e4b0c5da7f2a992f6b       Region Svyaz Konsalt LLC
# 9998  c0c21bbfa46f07ce61896628f5aa8836                   Tele2 Russia
# 9999  da2f265f2a1de1fff301881f77bbe9f0                   PJSC MegaFon
#
#                                            landing_page page_language  \
# 0     https://incanto.eu/?utm_source=getintent&utm_m...          None
# 1     https://incanto.eu/?utm_source=getintent&utm_m...          None
# 2     https://www.mvideo.ru/?utm_source=getintentdyn...            ru
# 3     https://www.mvideo.ru/?utm_source=getintentdyn...            ru
# 4     https://www.mvideo.ru/?utm_source=getintentdyn...            ru
# ...                                                 ...           ...
# 9995  https://incanto.eu/actions/khlopkovye-mayki-50...            ru
# 9996  https://www.mvideo.ru/?utm_source=getintentdyn...            ru
# 9997  https://incanto.eu/actions/khlopkovye-mayki-50...            ru
# 9998  https://www.mvideo.ru/?utm_source=getintentdyn...          None
# 9999  https://incanto.eu/?utm_source=getintent&utm_m...            ru
#
#       ssp_event_id        ssp               tag_id publisher_id  ...  \
# 0      5friJXI0gxS    ohmybid     6ae23bce1c8c4e55           87  ...
# 1      xegyvF0fCt7   buzzoola              1217284        15747  ...
# 2       QYMZhsIbgI    ohmybid       a8ac3391dabe31           90  ...
# 3      5icvt0bMxNT    ohmybid     a11f3ad5b41c1200           88  ...
# 4      5QcQe2TFB3y  skyadvert                 None         1095  ...
# ...            ...        ...                  ...          ...  ...
# 9995   gTjgTabTe9y   buzzoola              4721999        15737  ...
# 9996  ueH3m736GimJ  yandex_hb  66_970x250_alfadart           66  ...
# 9997   7GHCW8g8j5t       sape            364068891   3821988650  ...
# 9998   PhmdiL9wxCg        umg     d848fa0bf98f8691           90  ...
# 9999   uZYFmdMRtmY   buzzoola              1241289        17111  ...
#
#                           accept_language  ua_device_type    ua_os  \
# 0                                    None         DESKTOP  WINDOWS
# 1                                    None      SMARTPHONE  ANDROID
# 2                                    None         DESKTOP  WINDOWS
# 3                                    None         DESKTOP  WINDOWS
# 4                                    None      SMARTPHONE  ANDROID
# ...                                   ...             ...      ...
# 9995                                 None         DESKTOP  WINDOWS
# 9996  ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7         DESKTOP  WINDOWS
# 9997                                 None         DESKTOP  WINDOWS
# 9998                                 None      SMARTPHONE  ANDROID
# 9999                                 None      SMARTPHONE  ANDROID
#
#       ua_browser ua_third_party_cookie ua_os_version ua_browser_version  \
# 0         YANDEX                  True            10          23.11.0.0
# 1         CHROME                  True            10          120.0.0.0
# 2         CHROME                  True            10          109.0.0.0
# 3          OPERA                  True            10          106.0.0.0
# 4         CHROME                  True            10          120.0.0.0
# ...          ...                   ...           ...                ...
# 9995      CHROME                  True            10          120.0.0.0
# 9996      CHROME                  True            10          120.0.0.0
# 9997       OPERA                  True            10          105.0.0.0
# 9998      CHROME                  True            11     120.0.6099.230
# 9999      CHROME                  True            10          120.0.0.0
#
#      ua_parsing_type  ua_type  user_status
# 0                  0        1           11
# 1                  0        1           11
# 2                  0        1            1
# 3                  0        1            1
# 4                  0        3            1
# ...              ...      ...          ...
# 9995               0        1           11
# 9996               0        1            1
# 9997               0        1            1
# 9998               0        3            1
# 9999               0        3            1
#
# [10000 rows x 60 columns]

# %% [markdown]
# Сторонняя конверсия

# %%
import dask.dataframe as dd

third_party_conversions =  pd.read_csv('third_party_conversions2.csv')

third_party_conversions
# Out:
#       Unnamed: 0  advertiser_id   utm_source search_engine search_terms  \
# 0         862294          12453       yandex           NaN          NaN
# 1        2254377          12453  Yandex_maps           NaN          NaN
# 2        1357463          12453      advcake           NaN          NaN
# 3        3586631          12453          NaN        google          NaN
# 4        2774390          12453          NaN           NaN          NaN
# ...          ...            ...          ...           ...          ...
# 9995     1961932          12453       yandex           NaN          NaN
# 9996     1005175          12453          NaN           NaN          NaN
# 9997     3867886          11527          NaN           NaN          NaN
# 9998     1791899          12453          NaN           NaN          NaN
# 9999     3641395          12453           mt           NaN          NaN
#
#                                           user_segments                 time  \
# 0     48085,44985,44127,52109,45117,42809,52965,5296...  2024-01-03 13:38:55
# 1                                     53604,39804,53631  2024-01-13 10:03:35
# 2     44655,18667,44127,44589,53560,42940,44128,4465...  2024-01-04 17:35:00
# 3                         52055,52054,39804,53631,53604  2024-01-13 20:11:51
# 4                                                   NaN  2024-01-11 18:22:24
# ...                                                 ...                  ...
# 9995  44655,2185,44622,44127,43896,42891,42915,15773...  2024-01-21 11:10:15
# 9996  52999,44655,44985,44622,40334,40335,51878,4511...  2024-01-22 14:50:59
# 9997  48085,8179,44985,44622,2177,18601,44589,53362,...  2024-01-22 20:51:12
# 9998  48085,44622,45018,40335,46369,43895,44620,4488...  2024-01-20 18:37:05
# 9999                                              39804  2024-01-11 21:25:34
#
#      region_code             city zip_code  ...  \
# 0             77           Moskva   104015  ...
# 1             78  Sankt-Peterburg   190121  ...
# 2             66    Yekaterinburg   620075  ...
# 3            NaN              NaN      NaN  ...
# 4             77           Moskva   104015  ...
# ...          ...              ...      ...  ...
# 9995          78  Sankt-Peterburg   190000  ...
# 9996          77           Moskva   104015  ...
# 9997          35          Vologda   160010  ...
# 9998          64          Saratov   410999  ...
# 9999          71          Donskoy   301760  ...
#
#                                    accept_language  ua_device_type    ua_os  \
# 0              ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7         DESKTOP    LINUX
# 1              ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7      SMARTPHONE  ANDROID
# 2     ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7,sr;q=0.6         DESKTOP  WINDOWS
# 3              ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7         DESKTOP  WINDOWS
# 4              ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7         DESKTOP  WINDOWS
# ...                                            ...             ...      ...
# 9995           ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7      SMARTPHONE  ANDROID
# 9996           ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7      SMARTPHONE  ANDROID
# 9997           ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7      SMARTPHONE  ANDROID
# 9998           ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7      SMARTPHONE  ANDROID
# 9999           ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7      SMARTPHONE  ANDROID
#
#      ua_browser  ua_third_party_cookie ua_os_version ua_browser_version  \
# 0        CHROME                   True           NaN          119.0.0.0
# 1        CHROME                   True            12          108.0.0.0
# 2        CHROME                   True            10          120.0.0.0
# 3        CHROME                   True            10          120.0.0.0
# 4        CHROME                   True            10          120.0.0.0
# ...         ...                    ...           ...                ...
# 9995     CHROME                   True           NaN                NaN
# 9996      OPERA                   True            10    79.6.4195.77168
# 9997     CHROME                   True            10          120.0.0.0
# 9998     CHROME                   True            10          120.0.0.0
# 9999     CHROME                   True            10          120.0.0.0
#
#      ua_parsing_type ua_type   conversion_name
# 0                  0       1  implicit_depth_2
# 1                  0       3  implicit_depth_2
# 2                  0       1  implicit_depth_2
# 3                  0       1  implicit_depth_2
# 4                  0       1              cart
# ...              ...     ...               ...
# 9995               1       3               200
# 9996               0       3  implicit_depth_2
# 9997               0       3           pereyti
# 9998               0       3                10
# 9999               0       3                10
#
# [10000 rows x 27 columns]

# %% [markdown]
# **Мержим**

# %%
df = train_views.merge(train_actions[(train_actions.conversion_name == 'cart') \
                                         & (train_actions.is_post_click == 1)][['ssp_event_id', 'is_post_click']],
                           how='left', on='ssp_event_id')
df.is_post_click.fillna(0, inplace=True)
df.drop('ssp_event_id', inplace=True, axis=1)

# rename target column
df['label'] = df['is_post_click']
df.drop('is_post_click', inplace=True, axis=1)
# Out:
# /tmp/ipykernel_488/2416803855.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.is_post_click.fillna(0, inplace=True)

# %% [markdown]
# # Признаки
# смотрим на признак, если важен то начинаем его причесывать
# сначала приводим его к адекватному виду (например url нельзя нормально запихнуть в catboost, слишком много категорий получится, поэтому вырезаем из url домен), заполняем пропуски, если плохой то отбрасываем

# %% [markdown]
#  - **landing_page**: Страница, на которую перейдет пользователь, если кликнет по рекламе
#  - **city**: город юзера
#  - **do_not_track** - Разрешен ли трекинг пользователя в настройках браузера
#  - **ua_type** -Тип user agent-a
#  - **is_mobile_optimized_site** - оптимизирован ли сайт для мобильных устройств.
#  - **search_engine** - поисковик, через который пришел пользователь.
#  - **ua_device_type** - Тип устройства
#  - **user_fraud_state** - Является ли пользователь фродовым
#  -  **user_status** статус пользователя (встречался ли нам он ранее и способ детекции)
#  - **creative_size** - Размеры рекламы

# %%
from urllib.parse import urlparse
def preprocess_data(df):
    '''Обработка основных признаков'''
    # Обработка landing_page: извлечение домена
    df['landing_page_domain'] = df['landing_page'].apply(lambda x: urlparse(x).netloc if pd.notnull(x) else 'unknown')
    
    # Обработка city: если город встречается более 100 раз, сохраняем, иначе заменяем на 'other'
    city_counts = df['city'].value_counts()
    cities_more_than_100 = city_counts[city_counts >= 100].index
    df['city'] = df['city'].apply(lambda x: x if x in cities_more_than_100 else 'other')
    
    # Заполнение пропусков для ua_type и преобразование в строку
    df['ua_type'] = df['ua_type'].fillna('unknown').astype(str)
    

    # НАДО ЭТИ ТЕСТИТЬ do_not_track, is_mobile_optimized_site и search_engine (очень много unknown)
    df['do_not_track'] = df['do_not_track'].fillna('unknown').astype(str)
    df['is_mobile_optimized_site'] = df['is_mobile_optimized_site'].fillna('unknown').astype(str)
    df['search_engine'] = df['search_engine'].fillna('unknown').astype(str)
    
    
    df['ua_device_type'] = df['ua_device_type'].fillna('unknown').astype(str)
    df['user_fraud_state'] = df['user_fraud_state'].fillna('unknown').astype(str)
    df['user_status'] = df['user_status'].fillna('unknown').astype(str)
    
    # Агрегация редких значений в 'creative_size'
    top_creative_sizes = set(df['creative_size'].value_counts().nlargest(10).index)  # Топ 10 самых частых размеров
    df['creative_size'] = df['creative_size'].apply(lambda x: x if x in top_creative_sizes else 'other').astype('category')
  
    return df

df2 = preprocess_data(df)

# %%
cat_features = ['landing_page_domain', 'city', 'ua_type', 'do_not_track', 
                'is_mobile_optimized_site', 'search_engine', 
                'ua_device_type', 'user_fraud_state', 'user_status', 'creative_size']

df2['label']  # Целевая переменная
